# %% [markdown]
# # <span style="color:blue">Consumer Group</span>
#
# ## Definition
#
# A Consumer Group is a collection of consumers that work together to consume data from a Kafka topic.
#
# ### Why Do We Need Consumer Groups?
#
# Suppose we have:
#
# ```text
# Orders Topic
# ```
#
# and only one consumer:
#
# ```text
# Orders Topic
#       ↓
#       C1
# ```
#
# If millions of messages arrive every minute, a single consumer may not be able to process them efficiently.
#
# To scale message processing, Kafka introduces Consumer Groups.
#
# ---
#
# ## Example
#
# Topic:
#
# ```text
# Orders
# ```
#
# Partitions:
#
# ```text
# P0
# P1
# P2
# ```
#
# Consumer Group:
#
# ```text
# Group-A
#
# C1
# C2
# C3
# ```
#
# Kafka assigns:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
# ```
#
# This enables parallel processing.
#
# ---
#
# # Consumer Group Architecture
#
# ```text
#                 Orders Topic
#
#         ┌─────────┬─────────┬─────────┐
#         │         │         │
#         ▼         ▼         ▼
#
#        P0        P1        P2
#
#         │         │         │
#
#         ▼         ▼         ▼
#
#        C1        C2        C3
#
#       (Group-A)
# ```
#
# Each partition is assigned to only one consumer within the same group.
#
# ---
#
# ## Golden Rule ⭐
#
# Within the same Consumer Group:
#
# ```text
# 1 Partition = 1 Consumer
# ```
#
# A partition can be assigned to only one consumer within a group.
#
# ---
#
# ### Invalid Example
#
# ```text
# P0 → C1
#
# P0 → C2
# ```
#
# Reason:
#
# ```text
# Duplicate Processing
# ```
#
# Kafka prevents this.
#
# ---
#
# # Consumer Count vs Partition Count
#
# ## Case 1: Partitions = Consumers
#
# ```text
# Partitions = 3
#
# Consumers = 3
# ```
#
# Assignment:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
# ```
#
# Best scenario.
#
# ---
#
# ## Case 2: Partitions > Consumers
#
# ```text
# Partitions = 6
#
# Consumers = 3
# ```
#
# Assignment:
#
# ```text
# P0,P1 → C1
#
# P2,P3 → C2
#
# P4,P5 → C3
# ```
#
# A consumer can consume multiple partitions.
#
# ---
#
# ## Case 3: Consumers > Partitions
#
# ```text
# Partitions = 3
#
# Consumers = 5
# ```
#
# Assignment:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
#
# C4 → Idle
#
# C5 → Idle
# ```
#
# Extra consumers remain idle.
#
# ---
#
# ## Maximum Active Consumers ⭐
#
# Formula:
#
# ```text
# Maximum Active Consumers
# =
# Number Of Partitions
# ```
#
# Example:
#
# ```text
# Partitions = 5
#
# Consumers = 10
# ```
#
# Result:
#
# ```text
# 5 Active Consumers
#
# 5 Idle Consumers
# ```
#
# ---
#
# # Consumer Group Offset
#
# Each Consumer Group maintains its own offset.
#
# Example:
#
# ```text
# Group-A → Offset 100
#
# Group-B → Offset 50
# ```
#
# Both groups track progress independently.
#
# ---
#
# ## Why Is This Important?
#
# Because multiple groups can process the same topic independently.
#
# Example:
#
# ```text
# Orders Topic
# ```
#
# ```text
# Analytics Group → Offset 500
#
# Fraud Group → Offset 200
#
# Notification Group → Offset 1000
# ```
#
# Each group maintains its own progress.
#
# ---
#
# # Multiple Consumer Groups
#
# Topic:
#
# ```text
# Orders
# ```
#
# Consumer Groups:
#
# ```text
# Analytics Group
#
# Fraud Group
#
# Notification Group
# ```
#
# Architecture:
#
# ```text
# Orders Topic
#         ↓
#
#  ┌────────┬─────────┬─────────────┐
#  ▼        ▼         ▼
#
# Analytics Fraud Notification
# ```
#
# Each group receives the same message independently.
#
# ---
#
# ## Why Multiple Consumer Groups?
#
# Suppose an order is created:
#
# ```text
# Order Created
# ```
#
# The same event can be consumed by:
#
# ```text
# Analytics Team
#
# Fraud Service
#
# Notification Service
#
# Billing Service
# ```
#
# This is one of Kafka's biggest advantages.
#
# ---
#
# # Consumer Group ID
#
# Every Consumer Group has a unique identifier.
#
# Example:
#
# ```properties
# group.id=analytics-group
# ```
#
# ```properties
# group.id=fraud-group
# ```
#
# Kafka uses group.id to:
#
# ✅ Track Offsets
#
# ✅ Manage Consumers
#
# ✅ Assign Partitions
#
# ✅ Coordinate Rebalancing
#
# ---
#
# # Rebalancing ⭐⭐⭐
#
# ## What is Rebalancing?
#
# Rebalancing is the process of redistributing partitions among consumers when membership of a consumer group changes.
#
# ---
#
# ## Scenario 1: New Consumer Joins
#
# Before:
#
# ```text
# P0 → C1
#
# P1 → C2
# ```
#
# New Consumer:
#
# ```text
# C3
# ```
#
# After Rebalance:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
# ```
#
# ---
#
# ## Scenario 2: Consumer Leaves
#
# Before:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
# ```
#
# Consumer C2 crashes.
#
# After Rebalance:
#
# ```text
# P0 → C1
#
# P1 → C1
#
# P2 → C3
# ```
#
# Partitions are reassigned automatically.
#
# ---
#
# ## Scenario 3: New Partitions Added
#
# Before:
#
# ```text
# P0 → C1
#
# P1 → C2
# ```
#
# New Partition Added:
#
# ```text
# P2
# ```
#
# Kafka may rebalance and redistribute workload.
#
# ---
#
# ## When Does Rebalancing Happen?
#
# ✅ Consumer Joins
#
# ✅ Consumer Leaves
#
# ✅ Consumer Crash
#
# ✅ New Partitions Added
#
# ✅ Group Restart
#
# ---
#
# ## Benefits Of Rebalancing
#
# ✅ Load Balancing
#
# ✅ Fault Tolerance
#
# ✅ Automatic Recovery
#
# ✅ Better Resource Utilization
#
# ---
#
# ## Rebalancing Drawback
#
# During rebalance:
#
# ```text
# Consumers temporarily stop processing
# ```
#
# Too many rebalances can impact performance.
#
# ---
#
# # Real World Example
#
# Uber:
#
# ```text
# ride_requests topic
# ```
#
# Consumer Groups:
#
# ```text
# Driver Matching
#
# Pricing
#
# Fraud Detection
#
# Analytics
# ```
#
# A single ride request can be consumed by all groups independently.
#
# ---
#
# # Benefits of Consumer Groups
#
# ✅ Parallel Processing
#
# ✅ Scalability
#
# ✅ Load Balancing
#
# ✅ Fault Tolerance
#
# ✅ Better Resource Utilization
#
# ✅ Distributed Processing
#
# ✅ Independent Applications
#
# ---
#
# # Quick Revision
#
# ```text
# Topic
#    ↓
# Partitions
#    ↓
# Consumer Group
#    ↓
# Consumers
# ```
#
# ---
#
# ### Golden Rule
#
# ```text
# 1 Partition
#       =
# 1 Consumer
#
# (within same consumer group)
# ```
#
# ---
#
# ### Maximum Active Consumers
#
# ```text
# Maximum Active Consumers
# =
# Number Of Partitions
# ```
#
# ---
#
# ### Consumer Group Offset
#
# ```text
# Each Consumer Group
# Maintains Its Own Offset
# ```
#
# ---
#
# ### Rebalancing
#
# ```text
# Join
# Leave
# Crash
# Add Partition
#      ↓
# Rebalance
# ```
#
# ---
#
# # <span style="color:red">Consumer Group Interview Questions & Answers</span>
#
# ## Q1. What is a Consumer Group?
#
# A Consumer Group is a collection of consumers that work together to consume messages from a Kafka topic.
#
# ---
#
# ## Q2. Why Do We Need Consumer Groups?
#
# ✅ Parallel Processing
#
# ✅ Scalability
#
# ✅ Load Balancing
#
# ✅ Faster Consumption
#
# ---
#
# ## Q3. What Is The Golden Rule Of Consumer Groups?
#
# ```text
# 1 Partition = 1 Consumer
# (within the same consumer group)
# ```
#
# ---
#
# ## Q4. Can Multiple Consumers Read The Same Partition In The Same Consumer Group?
#
# ❌ No
#
# Kafka does not allow this.
#
# ---
#
# ## Q5. Can One Consumer Read Multiple Partitions?
#
# ✅ Yes
#
# A consumer can consume data from multiple partitions.
#
# ---
#
# ## Q6. Can Multiple Consumer Groups Consume The Same Topic?
#
# ✅ Yes
#
# Each group receives the same messages independently.
#
# ---
#
# ## Q7. What Is The Maximum Number Of Active Consumers?
#
# ```text
# Number Of Partitions
# ```
#
# ---
#
# ## Q8. What Happens If Consumers > Partitions?
#
# Extra consumers remain idle.
#
# ---
#
# ## Q9. What Happens If Partitions > Consumers?
#
# One consumer consumes multiple partitions.
#
# ---
#
# ## Q10. What Is Consumer Group ID?
#
# A unique identifier used by Kafka to manage a consumer group.
#
# Example:
#
# ```text
# group.id=analytics-group
# ```
#
# ---
#
# ## Q11. Why Is Consumer Group ID Important?
#
# Kafka uses it to:
#
# ✅ Track Offsets
#
# ✅ Manage Consumers
#
# ✅ Assign Partitions
#
# ---
#
# ## Q12. Does Every Consumer Group Have Its Own Offset?
#
# ✅ Yes
#
# Each group tracks offsets independently.
#
# ---
#
# ## Q13. Can Two Consumer Groups Have Different Offsets?
#
# ✅ Yes
#
# Example:
#
# ```text
# Group-A → Offset 100
#
# Group-B → Offset 500
# ```
#
# ---
#
# ## Q14. What Is Rebalancing?
#
# Rebalancing is the redistribution of partitions among consumers when group membership changes.
#
# ---
#
# ## Q15. When Does Rebalancing Happen?
#
# ✅ Consumer Joins
#
# ✅ Consumer Leaves
#
# ✅ Consumer Crashes
#
# ✅ New Partitions Added
#
# ---
#
# ## Q16. Why Is Rebalancing Needed?
#
# ✅ Load Balancing
#
# ✅ Fault Recovery
#
# ✅ Workload Redistribution
#
# ---
#
# ## Q17. What Happens During Rebalancing?
#
# Kafka reassigns partitions among available consumers.
#
# ---
#
# ## Q18. What Is The Drawback Of Rebalancing?
#
# Consumers temporarily pause processing during rebalance.
#
# ---
#
# ## Q19. What Happens To Offsets During Rebalancing?
#
# Kafka retains committed offsets.
#
# Consumers continue from the last committed offset after reassignment.
#
# ---
#
# ## Q20. How Does Kafka Achieve Parallel Processing?
#
# Using:
#
# ```text
# Partitions + Consumer Groups
# ```
#
# ---
#
# ## Q21. Can A Consumer Belong To Multiple Consumer Groups?
#
# ❌ No
#
# A consumer instance belongs to one consumer group at a time.
#
# ---
#
# ## Q22. How Many Consumers Should A Consumer Group Ideally Have?
#
# Best Practice:
#
# ```text
# Consumers ≈ Partitions
# ```
#
# ---
#
# ## Q23. Why Are Consumer Groups Important For Data Engineering?
#
# ✅ Streaming Pipelines
#
# ✅ Scalability
#
# ✅ Distributed Processing
#
# ✅ Independent Downstream Systems
#
# ---
#
# ## Q24. What Is The Main Benefit Of Multiple Consumer Groups?
#
# The same event can be processed independently by multiple applications.
#
# Example:
#
# ```text
# Orders Topic
#
# Analytics Group
#
# Fraud Group
#
# Notification Group
# ```
#
# ---
#
# ## Q25. Real World Example Of Consumer Groups?
#
# Uber:
#
# ```text
# ride_requests
# ```
#
# Consumer Groups:
#
# ```text
# Driver Matching
#
# Pricing
#
# Fraud Detection
#
# Analytics
# ```
#
# All groups process the same event independently.
#
# ---
#
# ## Q26. Can Kafka Work Without Consumer Groups?
#
# ✅ Yes
#
# But you lose:
#
# ✅ Scalability
#
# ✅ Parallel Processing
#
# ✅ Load Balancing
#
# ---
#
# ## Q27. What Is The Relationship Between Partitions And Consumer Groups?
#
# Partitions determine the maximum parallelism available to a consumer group.
#
# ---
#
# ## Most Important Interview Statement ⭐
#
# ```text
# Partitions provide scalability.
#
# Consumer Groups provide parallel processing.
#
# Together they make Kafka highly scalable.
# ```

# %%
print("Partition")

# %% [markdown]
# # <span style="color:green">Partition Deep Dive</span>
#
# ## What is a Partition?
#
# A Partition is a physical division of a Kafka Topic.
#
# Example:
#
# ```text
# Topic: Orders
# ```
#
# Without Partition:
#
# ```text
# Orders Topic
#
# Order1
# Order2
# Order3
# Order4
# ```
#
# With Partitions:
#
# ```text
# Orders Topic
#
# P0
# P1
# P2
# ```
#
# Messages are distributed across partitions.
#
# ```text
# P0 → O1 O4 O7
#
# P1 → O2 O5 O8
#
# P2 → O3 O6 O9
# ```
#
# ---
#
# ## Why Do We Need Partitions?
#
# Suppose:
#
# ```text
# 10 Million Messages / Second
# ```
#
# One queue cannot handle such traffic efficiently.
#
# Solution:
#
# ```text
# Split Data Across Partitions
# ```
#
# ---
#
# ## Benefits of Partitions
#
# ### 1. Scalability
#
# ```text
# More Partitions
# =
# More Capacity
# ```
#
# ---
#
# ### 2. Parallel Processing
#
# Without Partitions:
#
# ```text
# 1 Consumer
# ```
#
# With Partitions:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
# ```
#
# Multiple consumers can process data simultaneously.
#
# ---
#
# ### 3. Load Distribution
#
# Partitions can be distributed across brokers.
#
# ```text
# P0 → Broker1
#
# P1 → Broker2
#
# P2 → Broker3
# ```
#
# This reduces load on a single broker.
#
# ---
#
# ### 4. Better Throughput
#
# Kafka can process much more data because messages are distributed across multiple partitions.
#
# ---
#
# # Partition Assignment
#
# Producer decides which partition receives a message.
#
# Kafka supports multiple partitioning strategies.
#
# ---
#
# ## Round Robin Partitioning
#
# When no key is provided:
#
# ```text
# Msg1 → P0
#
# Msg2 → P1
#
# Msg3 → P2
#
# Msg4 → P0
#
# Msg5 → P1
# ```
#
# Messages are distributed evenly.
#
# ---
#
# ## Key-Based Partitioning ⭐
#
# Producer provides a key.
#
# Example:
#
# ```text
# CustomerID = 1001
# ```
#
# Kafka calculates:
#
# ```text
# hash(customerID)
# ```
#
# Result:
#
# ```text
# 1001 → P1
#
# 1001 → P1
#
# 1001 → P1
# ```
#
# Same key always goes to the same partition.
#
# ---
#
# ## Why Key-Based Partitioning?
#
# To maintain ordering.
#
# Example:
#
# ```text
# Customer 1001
#
# Order Created
#
# Payment Success
#
# Order Shipped
#
# Order Delivered
# ```
#
# All events go to the same partition.
#
# Ordering is preserved.
#
# ---
#
# # Kafka Ordering Guarantee
#
# ## Interview Question
#
# Does Kafka guarantee ordering?
#
# Answer:
#
# ✅ Yes
#
# But only within a partition.
#
# ---
#
# ### Example
#
# ```text
# Partition P0
#
# Order1
# Order2
# Order3
# Order4
# ```
#
# Order is preserved.
#
# ---
#
# ### Across Partitions
#
# ```text
# P0 → Order1
#
# P1 → Order2
#
# P2 → Order3
# ```
#
# Global ordering is NOT guaranteed.
#
# ---
#
# ## How To Maintain Ordering?
#
# Use a partition key.
#
# Example:
#
# ```text
# Key = Customer_ID
# ```
#
# Result:
#
# ```text
# Same Customer
#       ↓
# Same Partition
#       ↓
# Ordering Preserved
# ```
#
# ---
#
# # Partition Count vs Consumer Count
#
# ## Case 1
#
# ```text
# Partitions = 1
#
# Consumers = 10
# ```
#
# Result:
#
# ```text
# 1 Active
#
# 9 Idle
# ```
#
# ---
#
# ## Case 2
#
# ```text
# Partitions = 3
#
# Consumers = 3
# ```
#
# Result:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
# ```
#
# Perfect utilization.
#
# ---
#
# ## Case 3
#
# ```text
# Partitions = 6
#
# Consumers = 3
# ```
#
# Result:
#
# ```text
# P0,P1 → C1
#
# P2,P3 → C2
#
# P4,P5 → C3
# ```
#
# One consumer can read multiple partitions.
#
# ---
#
# ## Case 4
#
# ```text
# Partitions = 3
#
# Consumers = 5
# ```
#
# Result:
#
# ```text
# P0 → C1
#
# P1 → C2
#
# P2 → C3
#
# C4 → Idle
#
# C5 → Idle
# ```
#
# ---
#
# ## Golden Rule ⭐
#
# ```text
# Maximum Active Consumers
# =
# Number Of Partitions
# ```
#
# Example:
#
# ```text
# Partitions = 10
#
# Consumers = 20
# ```
#
# Result:
#
# ```text
# 10 Active
#
# 10 Idle
# ```
#
# ---
#
# # Partition Skew ⭐
#
# ## What is Partition Skew?
#
# Partition Skew occurs when most messages go to a single partition.
#
# Example:
#
# ```text
# P0 → 90%
#
# P1 → 5%
#
# P2 → 5%
# ```
#
# ---
#
# ## Problems Caused By Partition Skew
#
# ✅ Uneven Processing
#
# ✅ Consumer Imbalance
#
# ✅ Slow Performance
#
# ✅ Broker Overload
#
# ✅ Hot Partition
#
# ---
#
# ## Cause
#
# Poor Partition Key.
#
# Example:
#
# Bad Key:
#
# ```text
# Country
#
# Status
#
# Gender
# ```
#
# Low cardinality.
#
# ---
#
# ## Better Partition Keys
#
# ```text
# Customer_ID
#
# Order_ID
#
# Transaction_ID
# ```
#
# High cardinality.
#
# ---
#
# ## Interview Point
#
# Always choose a partition key that distributes data evenly.
#
# ---
#
# # Increasing Partitions ⭐
#
# Kafka allows increasing partitions.
#
# Example:
#
# Before:
#
# ```text
# 3 Partitions
# ```
#
# After:
#
# ```text
# 6 Partitions
# ```
#
# ---
#
# ## Benefits
#
# ✅ More Parallelism
#
# ✅ More Scalability
#
# ✅ More Consumers
#
# ---
#
# ## Important Limitation
#
# When partitions increase:
#
# ```text
# Hash Calculation Changes
# ```
#
# This may impact:
#
# ```text
# Key Based Partitioning
# ```
#
# and
#
# ```text
# Ordering
# ```
#
# for future messages.
#
# ---
#
# ## Interview Point
#
# Increasing partitions may change key-to-partition mapping.
#
# ---
#
# # Real World Example
#
# Uber Ride Events:
#
# ```text
# ride_requests
# ```
#
# Partition Key:
#
# ```text
# driver_id
#
# or
#
# rider_id
# ```
#
# Benefit:
#
# ```text
# Same Rider Events
#       ↓
# Same Partition
#       ↓
# Ordering Maintained
# ```
#
# ---
#
# # Benefits of Partitions
#
# ✅ Scalability
#
# ✅ Parallel Processing
#
# ✅ Load Balancing
#
# ✅ Better Throughput
#
# ✅ Distributed Storage
#
# ✅ Consumer Scaling
#
# ---
#
# # Architecture Diagram
#
# ```text
#                      Orders Topic
#
#           ┌──────────┬──────────┬──────────┐
#           │          │          │
#           ▼          ▼          ▼
#
#          P0         P1         P2
#
#           │          │          │
#
#           ▼          ▼          ▼
#
#          C1         C2         C3
# ```
#
# ---
#
# # Quick Revision
#
# ```text
# Topic
#    ↓
# Partitions
#    ↓
# Distributed Storage
#    ↓
# Parallel Processing
#    ↓
# High Throughput
# ```
#
# ---
#
# ## Most Important Interview Statement
#
# ```text
# Kafka guarantees ordering only within a partition,
# not across partitions.
# ```
#
# ---
#
# # <span style="color:red">Partition Interview Questions & Answers</span>
#
# ## Q1. What is a Partition in Kafka?
#
# A Partition is a physical subdivision of a Kafka Topic used for scalability and parallel processing.
#
# ---
#
# ## Q2. Why Are Partitions Needed?
#
# ✅ Scalability
#
# ✅ Parallel Processing
#
# ✅ Load Distribution
#
# ✅ Higher Throughput
#
# ---
#
# ## Q3. What Is The Difference Between Topic And Partition?
#
# Topic:
#
# ```text
# Logical Category
# ```
#
# Partition:
#
# ```text
# Physical Division Of A Topic
# ```
#
# ---
#
# ## Q4. Does Kafka Guarantee Ordering?
#
# ✅ Yes, within a partition.
#
# ❌ No, across partitions.
#
# ---
#
# ## Q5. How Does Kafka Decide Which Partition Gets A Message?
#
# Using:
#
# ```text
# Round Robin
# ```
#
# or
#
# ```text
# Key-Based Partitioning
# ```
#
# ---
#
# ## Q6. What Is Key-Based Partitioning?
#
# Kafka uses:
#
# ```text
# hash(key)
# ```
#
# to determine the target partition.
#
# ---
#
# ## Q7. Why Is Key-Based Partitioning Important?
#
# It ensures related events go to the same partition and ordering is preserved.
#
# ---
#
# ## Q8. Can Two Partitions Have The Same Offset?
#
# ✅ Yes
#
# Offsets are unique only within a partition.
#
# ---
#
# ## Q9. What Happens If There Are More Consumers Than Partitions?
#
# Extra consumers remain idle.
#
# ---
#
# ## Q10. What Happens If There Are More Partitions Than Consumers?
#
# One consumer can consume multiple partitions.
#
# ---
#
# ## Q11. How Many Consumers Can Actively Consume From A Topic?
#
# ```text
# Maximum Active Consumers
# =
# Number Of Partitions
# ```
#
# ---
#
# ## Q12. What Is Partition Skew?
#
# Uneven distribution of data across partitions.
#
# Example:
#
# ```text
# P0 → 90%
#
# P1 → 5%
#
# P2 → 5%
# ```
#
# ---
#
# ## Q13. Why Is Partition Skew Bad?
#
# ✅ Uneven Load
#
# ✅ Slow Processing
#
# ✅ Consumer Imbalance
#
# ✅ Broker Overload
#
# ---
#
# ## Q14. What Is A Good Partition Key?
#
# Examples:
#
# ```text
# customer_id
#
# order_id
#
# transaction_id
# ```
#
# ---
#
# ## Q15. What Is A Poor Partition Key?
#
# Examples:
#
# ```text
# country
#
# status
#
# gender
# ```
#
# ---
#
# ## Q16. Can Partitions Be Increased Later?
#
# ✅ Yes
#
# Kafka supports increasing partitions.
#
# ---
#
# ## Q17. What Is The Risk Of Increasing Partitions?
#
# Key-to-partition mapping may change.
#
# Ordering for future records may be affected.
#
# ---
#
# ## Q18. Can Partitions Be Distributed Across Multiple Brokers?
#
# ✅ Yes
#
# Kafka distributes partitions across brokers.
#
# ---
#
# ## Q19. Why Are Partitions Important For Data Engineering?
#
# They provide:
#
# ✅ Scalability
#
# ✅ Parallel Processing
#
# ✅ High Throughput
#
# ✅ Distributed Data Processing
#
# ---
#
# ## Q20. Can A Single Consumer Read Multiple Partitions?
#
# ✅ Yes
#
# One consumer can consume many partitions.
#
# ---
#
# ## Q21. What Is The Main Building Block Of Kafka Scalability?
#
# ```text
# Partitions
# ```
#
# Kafka scales primarily through partitions.
#
# ---
#
# ## Q22. How Do You Maintain Ordering For A Particular Customer?
#
# Use:
#
# ```text
# Customer_ID
# ```
#
# as the partition key.
#
# ---
#
# ## Q23. What Happens If No Key Is Provided?
#
# Kafka generally uses:
#
# ```text
# Round Robin Partitioning
# ```
#
# to distribute messages.
#
# ---
#
# ## Q24. Is More Partitions Always Better?
#
# ❌ No
#
# Too many partitions create:
#
# ```text
# More Metadata
#
# More Network Overhead
#
# More Management Complexity
# ```
#
# ---
#
# ## Q25. What Is The Most Important Kafka Ordering Rule?
#
# ```text
# Ordering is guaranteed only within a partition.
# ```
